# %% [markdown]
# # Day_three_Assignment

# %%
import numpy as np

# %%
import pandas as pd

# %%
## Assignment - Explore this dataset using pandas...

df=pd.read_csv('https://download.bls.gov/pub/time.series/cu/cu.item',
                 sep='\t')

# %%
df
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 394   SS68023   Tax return preparation and other accounting fees
# 395   SSEA011                                  College textbooks
# 396  SSFV031A           Food at elementary and secondary schools
# 397   SSGE013                                 Infants' equipment
# 398   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            399
# 2                0          T              1
# 3                1          T            374
# 4                1          T            358
# ..             ...        ...            ...
# 394              4          T            352
# 395              3          T            314
# 396              3          T            122
# 397              3          T            355
# 398              3          T            165
#
# [399 rows x 5 columns]

# %%
df.head()
# Out:
#   item_code                                          item_name  display_level  \
# 0       AA0                               All items - old base              0
# 1      AA0R  Purchasing power of the consumer dollar - old ...              0
# 2       SA0                                          All items              0
# 3      SA0E                                             Energy              1
# 4     SA0L1                                All items less food              1
#
#   selectable  sort_sequence
# 0          T              2
# 1          T            399
# 2          T              1
# 3          T            374
# 4          T            358

# %%
df.tail()
# Out:
#     item_code                                         item_name  \
# 394   SS68023  Tax return preparation and other accounting fees
# 395   SSEA011                                 College textbooks
# 396  SSFV031A          Food at elementary and secondary schools
# 397   SSGE013                                Infants' equipment
# 398   SSHJ031                                Infants' furniture
#
#      display_level selectable  sort_sequence
# 394              4          T            352
# 395              3          T            314
# 396              3          T            122
# 397              3          T            355
# 398              3          T            165

# %%
df.shape
# Out:
# (399, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 399 entries, 0 to 398
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   item_code      399 non-null    object
#  1   item_name      399 non-null    object
#  2   display_level  399 non-null    int64
#  3   selectable     399 non-null    object
#  4   sort_sequence  399 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 15.7+ KB

# %%
df.describe()
# Out:
#        display_level  sort_sequence
# count     399.000000     399.000000
# mean        3.192982     200.000000
# std         1.817102     115.325626
# min         0.000000       1.000000
# 25%         2.000000     100.500000
# 50%         3.000000     200.000000
# 75%         4.000000     299.500000
# max         8.000000     399.000000

# %%
df['sort_sequence'].value_counts()
# Out:
# 399    1
# 125    1
# 127    1
# 128    1
# 129    1
#       ..
# 269    1
# 270    1
# 271    1
# 272    1
# 1      1
# Name: sort_sequence, Length: 399, dtype: int64

# %%
df[df['display_level']>4]
# Out:
#     item_code                                      item_name  display_level  \
# 36   SAF11211                                          Meats              5
# 114    SEFA01                 Flour and prepared flour mixes              5
# 115    SEFA02                               Breakfast cereal              5
# 116    SEFA03                          Rice, pasta, cornmeal              5
# 118    SEFB01                                          Bread              5
# ..        ...                                            ...            ...
# 352   SS18064                                Prepared salads              6
# 353   SS20021                                Whiskey at home              5
# 354   SS20022  Distilled spirits, excluding whiskey, at home              5
# 358   SS27051                Land-line interstate toll calls              5
# 359   SS27061                Land-line intrastate toll calls              5
#
#     selectable  sort_sequence
# 36           T             26
# 114          T              8
# 115          T              9
# 116          T             10
# 118          T             13
# ..         ...            ...
# 352          T            117
# 353          T            129
# 354          T            130
# 358          T            328
# 359          T            329
#
# [95 rows x 5 columns]

# %%
df.corr()
# Out:
#                display_level  sort_sequence
# display_level        1.00000       -0.70548
# sort_sequence       -0.70548        1.00000

# %%
df.dropna(axis=0)
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 394   SS68023   Tax return preparation and other accounting fees
# 395   SSEA011                                  College textbooks
# 396  SSFV031A           Food at elementary and secondary schools
# 397   SSGE013                                 Infants' equipment
# 398   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            399
# 2                0          T              1
# 3                1          T            374
# 4                1          T            358
# ..             ...        ...            ...
# 394              4          T            352
# 395              3          T            314
# 396              3          T            122
# 397              3          T            355
# 398              3          T            165
#
# [399 rows x 5 columns]

# %%
df.dropna(axis=1)
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 394   SS68023   Tax return preparation and other accounting fees
# 395   SSEA011                                  College textbooks
# 396  SSFV031A           Food at elementary and secondary schools
# 397   SSGE013                                 Infants' equipment
# 398   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            399
# 2                0          T              1
# 3                1          T            374
# 4                1          T            358
# ..             ...        ...            ...
# 394              4          T            352
# 395              3          T            314
# 396              3          T            122
# 397              3          T            355
# 398              3          T            165
#
# [399 rows x 5 columns]

# %%
df.dtypes
# Out:
# item_code        object
# item_name        object
# display_level     int64
# selectable       object
# sort_sequence     int64
# dtype: object
